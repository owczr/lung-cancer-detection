# %% [markdown]
# # Metadata

# %%
import pandas as pd

df = pd.read_csv("/home/student/Repositories/lung-cancer-detection/LIDC-IDRI/LIDC-IDRI_MetaData.csv")

# %%
df.describe()
# Out:
#        Number of images  File Size (Bytes)
# count       1308.000000       1.308000e+03
# mean         186.947248       1.017938e+08
# std          153.672580       7.702601e+07
# min            1.000000       6.909958e+06
# 25%          109.000000       5.735189e+07
# 50%          141.000000       7.421436e+07
# 75%          262.250000       1.380084e+08
# max          764.000000       4.021401e+08

# %%
df.head()
# Out:
#        Subject ID                                          Study UID  \
# 0  LIDC-IDRI-1001  1.3.6.1.4.1.14519.5.2.1.6279.6001.281499745765...
# 1  LIDC-IDRI-0778  1.3.6.1.4.1.14519.5.2.1.6279.6001.174809695196...
# 2  LIDC-IDRI-0813  1.3.6.1.4.1.14519.5.2.1.6279.6001.139110171863...
# 3  LIDC-IDRI-0710  1.3.6.1.4.1.14519.5.2.1.6279.6001.116146223752...
# 4  LIDC-IDRI-0410  1.3.6.1.4.1.14519.5.2.1.6279.6001.818775038273...
#
#   Study Description             Study Date  \
# 0               NaN  2000-01-01 00:00:00.0
# 1             CHEST  2000-01-01 00:00:00.0
# 2               NaN  2000-01-01 00:00:00.0
# 3             CHEST  2000-01-01 00:00:00.0
# 4    CT LUNG SCREEN  2000-01-01 00:00:00.0
#
#                                            Series ID    Series Description  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...                   NaN
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100332161840...              Recon 2:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1308 entries, 0 to 1307
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Subject ID          1308 non-null   object
#  1   Study UID           1308 non-null   object
#  2   Study Description   617 non-null    object
#  3   Study Date          1308 non-null   object
#  4   Series ID           1308 non-null   object
#  5   Series Description  464 non-null    object
#  6   Number of images    1308 non-null   int64
#  7   File Size (Bytes)   1308 non-null   int64
#  8   Collection Name     1308 non-null   object
#  9   Modality            1308 non-null   object
#  10  Manufacturer        1308 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 112.5+ KB

# %%
df["Modality"].unique()
# Out:
# array(['CT', 'DX', 'CR'], dtype=object)

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Number of images'}>,
#         <Axes: title={'center': 'File Size (Bytes)'}>]], dtype=object)

# %%
df["Manufacturer"].unique()
# Out:
# array(['SIEMENS', 'GE MEDICAL SYSTEMS', 'Philips', 'TOSHIBA',
#        'GE Healthcare""', 'KODAK', 'Philips Medical Systems',
#        'FUJI PHOTO FILM Co., ltd.', 'DeJarnette Research Systems'],
#       dtype=object)

# %%
df["Manufacturer"].value_counts()
# Out:
# Manufacturer
# GE MEDICAL SYSTEMS             896
# SIEMENS                        234
# Philips                         74
# TOSHIBA                         69
# Philips Medical Systems         16
# GE Healthcare""                  8
# KODAK                            5
# DeJarnette Research Systems      4
# FUJI PHOTO FILM Co., ltd.        2
# Name: count, dtype: int64

# %%
df["Study Description"].value_counts()
# Out:
# Study Description
# CT LUNG SCREEN            135
# CHEST, PA & LATERAL       107
# CHEST                      74
# CT THORAX W/CONTRAST       71
# CT CHEST O CONTR           32
# CHEST 2 VIEW               27
# CT GUIDED LUNG B           22
# CT CHEST WO CONTRAST       19
# CT THORAX WO IV CONTRA     18
# CT ANGIO CHEST (NON-CO     12
# CT ANGIO CHEST W&W/O C     11
# CHEST PA - LAT             11
# CT THORAX W/O CONTRAST     10
# CT CAP                      7
# CT CHEST W/ CONT            5
# CT CHEST W/O CON            5
# CAP                         4
# CT GUIDED LUNG BIOPSY       4
# CHEST PA AND LATERAL        3
# CHEST/ABD/PELVIS            2
# CT C/A                      2
# POST CHEST                  2
# CT CH/AB/PELVIS             2
# CT THORAX W IV CONTRAS      2
# CT C/A/P                    2
# e+1 CT LUNG SCREEN          1
# CHEST/ABD W/C               1
# CT CH/ABD/PELVIS            1
# CAP W/CON                   1
# CH-AB W/WO                  1
# ...

# %%
df = pd.read_csv("/home/student/Repositories/lung-cancer-detection/LIDC-IDRI/CT/all/metadata.csv")

# %%
df
# Out:
#                                             Series UID Collection  \
# 0    1.3.6.1.4.1.14519.5.2.1.6279.6001.493562949900...  LIDC-IDRI
# 1    1.3.6.1.4.1.14519.5.2.1.6279.6001.141365756818...  LIDC-IDRI
# 2    1.3.6.1.4.1.14519.5.2.1.6279.6001.179049373636...  LIDC-IDRI
# 3    1.3.6.1.4.1.14519.5.2.1.6279.6001.142026812390...  LIDC-IDRI
# 4    1.3.6.1.4.1.14519.5.2.1.6279.6001.170706757615...  LIDC-IDRI
# ..                                                 ...        ...
# 560  1.3.6.1.4.1.14519.5.2.1.6279.6001.200837896655...  LIDC-IDRI
# 561  1.3.6.1.4.1.14519.5.2.1.6279.6001.861997885565...  LIDC-IDRI
# 562  1.3.6.1.4.1.14519.5.2.1.6279.6001.465712338305...  LIDC-IDRI
# 563  1.3.6.1.4.1.14519.5.2.1.6279.6001.313683718840...  LIDC-IDRI
# 564  1.3.6.1.4.1.14519.5.2.1.6279.6001.257840703452...  LIDC-IDRI
#
#      3rd Party Analysis                           Data Description URI  \
# 0                   NaN  https://doi.org/10.7937/K9/TCIA.2015.LO9QL9SX
# ...
