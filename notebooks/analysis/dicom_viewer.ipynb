# %%
import pydicom

# %%
DICOM_PATH = "/home/student/Repositories/lung-cancer-detection/LIDC-IDRI/CT/test/LIDC-IDRI-0001/01-01-2000-NA-NA-35511/3000923.000000-NA-62357/1-1.dcm"

# %%
ds = pydicom.dcmread(DICOM_PATH)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(ds.pixel_array, cmap="bone")
