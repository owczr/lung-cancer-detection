# %%
import pydicom

# %%
DICOM_PATH = "/home/student/Repositories/lung-cancer-detection/LIDC-IDRI/CT/manifest-1600709154662/LIDC-IDRI/LIDC-IDRI-0001/01-01-2000-NA-NA-30178/3000566.000000-NA-03192/1-001.dcm"

# %%
ds = pydicom.dcmread(DICOM_PATH)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(ds.pixel_array, cmap="bone")
